# %% [markdown]
# #Pandas Basics:

# %% [markdown]
# ###Import data:

# %%
import pandas as pd

# %%
df=pd.read_excel('/content/mini excel.xlsl.xlsx')
print(df)
# Out:
#    S:no   Name  Age        Job
# 0     1  Anand   27      Sales
# 1     2  Ramya   25         HR
# 2     3  Navin   24  Marketing
# 3     4   Kani   26         DA
# 4     5   Ravi   23    Finance

# %% [markdown]
# ### Explore Series & Columns:

# %%
print(df.columns)
# Out:
# Index(['S:no', 'Name', 'Age', 'Job'], dtype='object')

# %%
print(df.head())
# Out:
#    S:no   Name  Age        Job
# 0     1  Anand   27      Sales
# 1     2  Ramya   25         HR
# 2     3  Navin   24  Marketing
# 3     4   Kani   26         DA
# 4     5   Ravi   23    Finance

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   S:no    5 non-null      int64
#  1   Name    5 non-null      object
#  2   Age     5 non-null      int64
#  3   Job     5 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 292.0+ bytes
# None

# %%
print(df["Job"])
# Out:
# 0        Sales
# 1           HR
# 2    Marketing
# 3           DA
# 4      Finance
# Name: Job, dtype: object

# %% [markdown]
# ### Add,Update,Delete Columns/Rows:

# %%
df['Salary']=([15000,20000,25000,18000,20000])

# %%
print(df)
# Out:
#    S:no   Name  Age        Job  Salary
# 0     1  Anand   27      Sales   15000
# 1     2  Ramya   25         HR   20000
# 2     3  Navin   24  Marketing   25000
# 3     4   Kani   26         DA   18000
# 4     5   Ravi   23    Finance   20000

# %%
df.loc[len(df)] = [6, 'Priya', 28, 'Teller', 15000]

# %%
print(df)
# Out:
#    S:no   Name  Age        Job  Salary
# 0     1  Anand   27      Sales   15000
# 1     2  Ramya   25         HR   20000
# 2     3  Navin   24  Marketing   25000
# 3     4   Kani   26         DA   18000
# 4     5   Ravi   23    Finance   20000
# 5     6  Priya   28     Teller   15000

# %%
df.drop('Salary',axis=1,inplace=True)
print(df)
# Out:
#    S:no   Name  Age        Job
# 0     1  Anand   27      Sales
# 1     2  Ramya   25         HR
# 2     3  Navin   24  Marketing
# 3     4   Kani   26         DA
# 4     5   Ravi   23    Finance
# 5     6  Priya   28     Teller

# %%
df.drop(5, axis=0, inplace=True)
print(df)
# Out:
#    S:no   Name  Age        Job
# 0     1  Anand   27      Sales
# 1     2  Ramya   25         HR
# 2     3  Navin   24  Marketing
# 3     4   Kani   26         DA
# 4     5   Ravi   23    Finance

# %%
df.index = ['E01','E02','E03','E04','E05']
print(df)
# Out:
#      S:no   Name  Age        Job
# E01     1  Anand   27      Sales
# E02     2  Ramya   25         HR
# E03     3  Navin   24  Marketing
# E04     4   Kani   26         DA
# E05     5   Ravi   23    Finance

# %%
df.sort_values(by='Age',inplace=True)
print(df)
# Out:
#      S:no   Name  Age        Job
# E05     5   Ravi   23    Finance
# E03     3  Navin   24  Marketing
# E02     2  Ramya   25         HR
# E04     4   Kani   26         DA
# E01     1  Anand   27      Sales
